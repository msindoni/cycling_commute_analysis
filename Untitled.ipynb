# %%
import pandas as pd
import re #regular expressions, used for searching strings in a systematic way
import cv2 #allows you to work with 
import plotly #basic image analysis/manipulation
import plotly.graph_objects as go #interavtive graphing
import numpy as np #array manipulation
import seaborn as sns #graphing tool
import matplotlib.pyplot as plt #graphing tool
from scipy.optimize import curve_fit #stats/data analysis
import math #bacis math functions
import os

from cycling_helper_functions import*

# %%
# with open('Z:/All_Staff/Grandl Lab/Michael Sindoni/mem_imaging_project/Pz1_Pz2_splice_expt/pz2_variant_tension_1.csv', 'r') as fhand:
with open('C:/Users/msind/OneDrive/Desktop/github_projects/cycling_commute_analysis/commute_data.csv', 'r') as fhand:
# with open('D:/tension_expt_2023_06/weekend_2023_07_08/pz2_variant_tension.csv', 'r') as fhand:
    df_master = pd.read_csv(fhand)

# %%
df_master.head()
# Out:
#    year  month  day_num   day_week there_total_time there_start_time  \
# 0  2022      9       15   Thursday               23             8.32
# 1  2022      9       16     Friday            23.16             8.12
# 2  2022      9       19     Monday            22.53             8.03
# 3  2022      9       20    Tuesday            21.53             8.39
# 4  2022      9       21  Wednesday            23.39             8.26
#
#   there_end_time there_temp there_real_feel there_dew_point  ... back_temp  \
# 0           8.55         59             DNR             DNR  ...        79
# 1           8.35         63             DNR             DNR  ...        84
# 2           8.26         66             DNR             DNR  ...       DNR
# 3           9.01         70             DNR             DNR  ...        90
# 4           8.49         67             DNR             DNR  ...        90
#
#   back_real_feel back_dew_point back_air_quality uv_back  back_weather  \
# 0            DNR            DNR              DNR     DNR         sunny
# 1            DNR            DNR              DNR     DNR         sunny
# 2            DNR            DNR              DNR     DNR           DNR
# 3            DNR            DNR              DNR     DNR  mostly sunny
# 4            DNR            DNR              DNR     DNR         sunny
#
#   hours_sleep physical_condition mental_condition incident?
# 0        9.47                  5                6         n
# 1        8.52                  6                7         n
# 2        8.53                  8                8         n
# 3        9.26                  8                8         n
# 4        8.13                  7                7         n
#
# [5 rows x 26 columns]

# %% [markdown]
# # Converting time to seconds

# %%
#generates a column with the desried total times converted to seconds
#also generates a column of normalized values
data=df_master.loc[(df_master['back_total_time_sec']>800) & (df_master['back_total_time_sec']<1500)] #removing outlier times
df_master=watch_time_to_sec(data, 'back_total_time')
# Out:
# not recorded:  2022 9 19
# not recorded:  2022 9 27
# not recorded:  2022 10 21
# not recorded:  2022 10 27
# not recorded:  2022 12 6
# not recorded:  2022 12 9
# not recorded:  2022 12 20
# not recorded:  2023 1 2
# not recorded:  2023 9 1
# not recorded:  2023 9 8
# C:\Users\msind\AppData\Local\Temp\ipykernel_7204\3471766806.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_master[column_name +'_sec']=seconds_list
# C:\Users\msind\AppData\Local\Temp\ipykernel_7204\3471766806.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_master[column_name +'_sec_norm']=df_master[column_name +'_sec']/max(seconds_list)

# %% [markdown]
# # Looking at relationship between speed and temperature

# %%
data=data.loc[(data['incident?']=='n') & pd.to_numeric(data['back_temp'], errors='coerce').notnull()] #removing values that are not numeric

# Convert 'there_temp' column to numeric
data['back_temp'] = pd.to_numeric(data['back_temp'])

plt.scatter(data['back_temp'], data['back_total_time_sec'])
# plt.ylim(0,)

# Compute correlation coefficient
correlation_coefficient = data['back_temp'].corr(data['back_total_time_sec'])

print("Correlation Coefficient:", correlation_coefficient)


x = np.array([min(data['back_temp']), max(data['back_temp'])])
y = correlation_coefficient * x  # y = mx
plt.plot(x, y, color='red', label=f'Correlation Line (r={correlation_coefficient:.2f})')


plt.show()
# Out:
# Correlation Coefficient: -0.21851912249380395

# %%
plt.figure(figsize=(8, 6))
sns.regplot(data=data, x='back_temp', y='back_total_time_sec', scatter_kws={'s': 100})  # Increase marker size
plt.xlabel('Back Temperature')
plt.ylabel('Back Total Time (sec)')
plt.title('Scatter Plot with Regression Line')
plt.grid(True)
plt.show()


from scipy.stats import pearsonr
# Compute Pearson correlation coefficient and p-value
correlation_coefficient, p_value = pearsonr(data['back_temp'], data['back_total_time_sec'])

print("Correlation Coefficient:", correlation_coefficient)
print("p-value:", p_value)
# Out:
# Correlation Coefficient: -0.2185191224938039
# p-value: 0.002265454027508723

# %%
data=data.loc[(data['incident?']=='n') & pd.to_numeric(data['there_temp'], errors='coerce').notnull()] #removing values that are not numeric

# Convert 'there_temp' column to numeric
data['there_temp'] = pd.to_numeric(data['back_temp'])

plt.scatter(data['back_temp'], data['back_total_time_sec'])
# plt.ylim(0,)

# Compute correlation coefficient
correlation_coefficient = data['back_temp'].corr(data['back_total_time_sec'])

print("Correlation Coefficient:", correlation_coefficient)


x = np.array([min(data['back_temp']), max(data['back_temp'])])
y = correlation_coefficient * x  # y = mx
plt.plot(x, y, color='red', label=f'Correlation Line (r={correlation_coefficient:.2f})')


plt.show()


plt.figure(figsize=(8, 6))
sns.regplot(data=data, x='there_temp', y='there_total_time_sec', scatter_kws={'s': 100})  # Increase marker size
plt.xlabel('There Temperature')
plt.ylabel('There Total Time (sec)')
plt.title('Scatter Plot with Regression Line')
plt.grid(True)
plt.show()


from scipy.stats import pearsonr
# Compute Pearson correlation coefficient and p-value
correlation_coefficient, p_value = pearsonr(data['there_temp'], data['there_total_time_sec'])

print("Correlation Coefficient:", correlation_coefficient)
print("p-value:", p_value)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In [69], line 2
#       1 plt.figure(figsize=(8, 6))
# ----> 2 sns.regplot(data=data, x='there_temp', y='there_total_time_sec', scatter_kws={'s': 100})  # Increase marker size
#       3 plt.xlabel('There Temperature')
#       4 plt.ylabel('There Total Time (sec)')
#
# File ~\anaconda3\envs\mem_imaging_2022\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\envs\mem_imaging_2022\lib\site-packages\seaborn\regression.py:863, in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     861 scatter_kws["marker"] = marker
#     862 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 863 plotter.plot(ax, scatter_kws, line_kws)
#     864 return ax
#
# File ~\anaconda3\envs\mem_imaging_2022\lib\site-packages\seaborn\regression.py:370, in _RegressionPlotter.plot(self, ax, scatter_kws, line_kws)
#     367     self.scatterplot(ax, scatter_kws)
#     369 if self.fit_reg:
# --> 370     self.lineplot(ax, line_kws)
#     372 # Label the axes
#     373 if hasattr(self.x, "name"):
#
# File ~\anaconda3\envs\mem_imaging_2022\lib\site-packages\seaborn\regression.py:413, in _RegressionPlotter.lineplot(self, ax, kws)
#     411 """Draw the model."""
#     412 # Fit the regression model
# --> 413 grid, yhat, err_bands = self.fit_regression(ax)
#     414 edges = grid[0], grid[-1]
#     416 # Get set default aesthetics
#
# File ~\anaconda3\envs\mem_imaging_2022\lib\site-packages\seaborn\regression.py:201, in _RegressionPlotter.fit_regression(self, ax, x_range, grid)
#     199         else:
#     200             x_min, x_max = ax.get_xlim()
# --> 201     grid = np.linspace(x_min, x_max, 100)
#     202 ci = self.ci
#     204 # Fit the regression
#
# File <__array_function__ internals>:180, in linspace(*args, **kwargs)
#
# File ~\anaconda3\envs\mem_imaging_2022\lib\site-packages\numpy\core\function_base.py:127, in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     123 div = (num - 1) if endpoint else num
#     125 # Convert float/complex array scalars to float, gh-3504
#     126 # and make sure one can use variables that have an __array_interface__, gh-6634
# --> 127 start = asanyarray(start) * 1.0
#     128 stop  = asanyarray(stop)  * 1.0
#     130 dt = result_type(start, stop, float(num))
#
# UFuncTypeError: ufunc 'multiply' did not contain a loop with signature matching types (dtype('<U2'), dtype('float64')) -> None

# %% [markdown]
# # Generating averages for all time and past 10 rides

# %%
data=df_master.loc[(df_master['back_total_time_sec']>800) & (df_master['back_total_time_sec']<1500)]


column_name='back_total_time_sec'
all_time_avg_list=[]
ten_day_average_list=[]
ride_count_list=[]

ride_count=1
total_sec_sum=0

for i in range(len(data)):

    #generating all time average
    total_sec_sum+=data[column_name].iloc[i]
    all_time_avg_list.append(total_sec_sum/ride_count)
    
    #generating ten day average
    if i<10: #first 10 will avaerage one at a time, not all 10 at once, same function as above, different list
        ten_day_average_list.append(total_sec_sum/ride_count)
    else:
        ten_day_average=(data[column_name].loc[i-9:i].sum())/10 #since indexing withy pandas is inclusive
        ten_day_average_list.append(ten_day_average)
    
    ride_count_list.append(ride_count)   
        
    ride_count+=1

# %%
plt.plot(ride_count_list, all_time_avg_list)

# %%
plt.plot(ride_count_list, ten_day_average_list)

# %%
df_master
# Out:
#      year  month  day_num   day_week there_total_time there_start_time  \
# 0    2022      9       15   Thursday               23             8.32
# 1    2022      9       16     Friday            23.16             8.12
# 2    2022      9       19     Monday            22.53             8.03
# 3    2022      9       20    Tuesday            21.53             8.39
# 4    2022      9       21  Wednesday            23.39             8.26
# ..    ...    ...      ...        ...              ...              ...
# 219  2024      2       20    Tuesday            25.13             7.43
# 220  2024      2       21  Wednesday            23.56             7.55
# 221  2024      2       26     Monday            24.29             7.43
# 222  2024      2       27    Tuesday            24.08              7.5
# 223  2024      2       28  Wednesday            22.44             7.52
#
#     there_end_time there_temp there_real_feel there_dew_point  ...  \
# 0             8.55         59             DNR             DNR  ...
# 1             8.35         63             DNR             DNR  ...
# 2             8.26         66             DNR             DNR  ...
# 3             9.01         70             DNR             DNR  ...
# 4             8.49         67             DNR             DNR  ...
# ..             ...        ...             ...             ...  ...
# 219           8.08         32              28              28  ...
# 220           8.19         33              28              28  ...
# 221           8.07         44              40              36  ...
# 222           8.14         51              50              42  ...
# 223           8.15         61              60              50  ...
#
#     back_real_feel back_dew_point back_air_quality uv_back   back_weather  \
# 0              DNR            DNR              DNR     DNR          sunny
# 1              DNR            DNR              DNR     DNR          sunny
# 2              DNR            DNR              DNR     DNR            DNR
# 3              DNR            DNR              DNR     DNR   mostly sunny
# 4              DNR            DNR              DNR     DNR          sunny
# ..             ...            ...              ...     ...            ...
# 219             51             31               32       0  mostly cloudy
# 220             50             35               36       0          sunny
# 221             60             43               44       0  partly cloudy
# 222             60             55               44       0         cloudy
# 223             69             58               43       0        drizzle
#
#     hours_sleep physical_condition mental_condition incident?  \
# 0          9.47                  5                6         n
# 1          8.52                  6                7         n
# 2          8.53                  8                8         n
# 3          9.26                  8                8         n
# 4          8.13                  7                7         n
# ..          ...                ...              ...       ...
# 219        8.37                  8                8         n
# 220        7.04                  7                8         n
# 221         7.2                  8                8         n
# 222        7.28                  8                7         n
# 223        7.15                  7                8         n
#
#     back_total_time_sec
# 0                  1440
# 1                   952
# 2                   952
# 3                  1125
# 4                  1033
# ..                  ...
# 219                1001
# 220                1122
# 221                 963
# 222                1099
# 223                1185
#
# [224 rows x 27 columns]

# %%
data = df_master.sort_values(by='back_total_time_sec')
data=data.loc[(data['back_total_time_sec']>800) & (data['back_total_time_sec']<1500)]
plt.hist(data['back_total_time_sec'],bins=100)

# %%
day=np.linspace(1, len(df_master), len(df_master))
df_master['day_num']=day

# %%
plt.scatter(df_master['day_num'], df_master['back_total_time_sec'])

# %%
df_cut=df_master.loc[df_master['back_total_time_sec']<1750]

# %%
max_time=df_cut['back_total_time_sec'].max()
normalized_list=df_cut['back_total_time_sec']/max_time
day=np.linspace(1, len(normalized_list), len(normalized_list))
plt.scatter(day, normalized_list)
plt.ylim(0,1)

# %%
data = df.sort_values(by='there_total_time')
plt.hist(data['there_total_time'],bins=200)

# %%
data = df.sort_values(by='hours_sleep')
plt.hist(data['hours_sleep'],bins=50)

# %%
data = df.sort_values(by='back_total_time')
plt.hist(data['back_total_time'],bins=100)

# %%
data
